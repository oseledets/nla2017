# %% [markdown]
# # Table of contents

# %% [markdown]
# **Course instructor: **
# Ivan Oseledets
#
# ** TAs:**
# Maxim Rakhuba,
# Marina Munkhoeva,
# Alexandr Katrutsa,
# Artem Nikitin,
# Valentin Khrulkov,
# Daniil Merkulov,
# Evgeny Ponomarev

# %% [markdown]
# | Week | Classes | Homework | Tests |
# |------|----------|----------|-------|
# |1| [General info](lectures/lecture-0.ipynb) <br> [Lecture 1 (Floating-point arithmetic, vector norms)](lectures/lecture-1.ipynb) <br> [Lecture 2 (Matrix norms, unitary matrices)](lectures/lecture-2.ipynb) <br> [Lecture 3 (Matvecs and matmuls, memory hierarchy, Strassen algorithm)](lectures/lecture-3.ipynb) | [Requirements](hw.pdf) <br> [Problem set 1](psets/pset1.ipynb) <br> Deadline: 12/11/17 (11:59 pm) | |
